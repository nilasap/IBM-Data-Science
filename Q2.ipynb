# %% [markdown]
# Display the last five rows of the tesla_revenue dataframe using the tail function. Upload a screenshot of the results.

# %%
# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install requests==2.26.0
# Out:
# Looking for: ['bs4==4.10.0']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━  13.7kB /  38.0MB @ 155.7kB/s  0.1s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━━━━━━━   5.0MB /  38.0MB @  26.2MB/s  0.2s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━━━━   4.2MB /  16.4MB @  21.8MB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━━  10.7MB /  38.0MB @  36.1MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   8.4MB /  16.4MB @  28.5MB/s  0.3s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  15.5MB /  38.0MB @  38.8MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━  10.5MB /  16.4MB @  30.2MB/s  0.4sconda-forge/noarch                                  16.4MB @  33.9MB/s  0.5s
# [+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  18.7MB /  38.0MB @  41.5MB/s  0.5s[+] 0.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  25.8MB /  38.0MB @  46.7MB/s  0.6s[+] 0.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━╸━━━━  32.7MB /  38.0MB @  50.0MB/s  0.7s[+] 0.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  0.8s[+] 0.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  0.9s[+] 1.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.0s[+] 1.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.1s[+] 1.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.2s[+] 1.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.3s[+] 1.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.4s[+] 1.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.5s[+] 1.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.6s[+] 1.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.7s[+] 1.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.8s[+] 1.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  1.9s[+] 2.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.0s[+] 2.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.1s[+] 2.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.2s[+] 2.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.3s[+] 2.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.4s[+] 2.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.5s[+] 2.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.6s[+] 2.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.7s[+] 2.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.8s[+] 2.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  2.9s[+] 3.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.0s[+] 3.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.1s[+] 3.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.2s[+] 3.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.3s[+] 3.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.4s[+] 3.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.5s[+] 3.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.6s[+] 3.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.7s[+] 3.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.8s[+] 3.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  3.9s[+] 4.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.0s[+] 4.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.1s[+] 4.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.2s[+] 4.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.3s[+] 4.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.4s[+] 4.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.5s[+] 4.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.6s[+] 4.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.7s[+] 4.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.8s[+] 4.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  4.9s[+] 5.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.0s[+] 5.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.1s[+] 5.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.2s[+] 5.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.3s[+] 5.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.4s[+] 5.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.5s[+] 5.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.6s[+] 5.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.7s[+] 5.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━╸━━  36.4MB /  38.0MB @  51.6MB/s  5.8sconda-forge/linux-64                                38.0MB @  52.2MB/s  5.8s
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package              Version  Build         Channel          Size
# ─────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────
#
#   + bs4                 4.10.0  hd8ed1ab_0    conda-forge       4kB
#   + libgcc              14.1.0  h77fa898_1    conda-forge     846kB
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────
#
#   - certifi           2024.6.2  pyhd8ed1ab_0  conda-forge     161kB
#   + certifi          2024.8.30  pyhd8ed1ab_0  conda-forge     164kB
#   - ca-certificates   2024.6.2  hbcca054_0    conda-forge     156kB
#   + ca-certificates  2024.8.30  hbcca054_0    conda-forge     159kB
#   - libgomp             13.2.0  h77fa898_6    conda-forge     420kB
#   + libgomp             14.1.0  h77fa898_1    conda-forge     460kB
#   - libgcc-ng           13.2.0  h77fa898_6    conda-forge     778kB
#   + libgcc-ng           14.1.0  h69a702a_1    conda-forge      52kB
#   - openssl              3.3.1  h4ab18f5_0    conda-forge       3MB
#   + openssl              3.3.2  hb9d3cd8_0    conda-forge       3MB
#
#   Downgrade:
# ─────────────────────────────────────────────────────────────────────
#
#   - beautifulsoup4      4.12.3  pyha770c72_0  conda-forge     118kB
#   + beautifulsoup4      4.10.0  pyha770c72_0  conda-forge      79kB
#
#   Summary:
#
#   Install: 2 packages
#   Upgrade: 5 packages
#   Downgrade: 1 packages
#
#   Total download: 5MB
#
# ─────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (3) ╸━━━━━━━━━━━━━━━━━━━━━━   0.0 B beautifulsoup4             0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0scertifi                                            163.8kB @   2.6MB/s  0.1s
# bs4                                                  4.3kB @  55.4kB/s  0.1s
# ca-certificates                                    159.0kB @   1.6MB/s  0.1s
# [+] 0.1s
# Downloading  (4) ━╸━━━━━━━━━━━━━━━━━━━━━ 478.6kB libgcc                     0.2s
# Extracting   (4) ━━━━━━━╸━━━━━━━━━━━━━━━       0 beautifulsoup4             0.0sbeautifulsoup4                                      79.2kB @ 558.4kB/s  0.1s
# libgomp                                            460.2kB @   2.3MB/s  0.1s
# [+] 0.2s
# Downloading  (3) ━━━━━━━━━╸━━━━━━━━━━━━━   2.1MB libgcc                     0.2s
# Extracting   (5) ━━━━━━━━╸━━━━━━━━━━━━━━       0 beautifulsoup4             0.0slibgcc-ng                                           52.2kB @ 262.2kB/s  0.1s
# libgcc                                             846.4kB @   4.2MB/s  0.2s
# [+] 0.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   4.7MB                            0.4s
# Extracting   (6) ━━━━╸━━━━━━━━━━━━━━━━━━       2 beautifulsoup4             0.3s[+] 0.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   4.7MB                            0.4s
# Extracting   (2) ━━━━━━━━━━━━━━━━╸━━━━━━       6 libgcc                     0.3s[+] 0.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   4.7MB                            0.4s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━━━       7 openssl                    0.4s
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ERROR conda.core.link:_execute(949): An error occurred while uninstalling package 'conda-forge/noarch::certifi-2024.6.2-pyhd8ed1ab_0'.
# Rolling back transaction: done
# [Errno 13] Permission denied: '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER' -> '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER.c~'
# ()
#
#
# [Errno 13] Permission denied: '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER' -> '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER.c~'
# ()
#
# Collecting lxml==4.6.4
#   Downloading lxml-4.6.4.tar.gz (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 78.6 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       /tmp/pip-install-vfiwr6r6/lxml_28f53a16aa514013b10b0521bd3b3faa/setup.py:67: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
#       Building lxml version 4.6.4.
#       Building without Cython.
#       Error: Please make sure the libxml2 and libxslt development packages are installed.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# Looking for: ['html5lib==1.1']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package              Version  Build         Channel           Size
# ──────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────
#
#   + html5lib               1.1  pyh9f0ad1d_0  conda-forge       91kB
#   + libgcc              14.1.0  h77fa898_1    conda-forge     Cached
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────
#
#   - certifi           2024.6.2  pyhd8ed1ab_0  conda-forge      161kB
#   + certifi          2024.8.30  pyhd8ed1ab_0  conda-forge     Cached
#   - ca-certificates   2024.6.2  hbcca054_0    conda-forge      156kB
#   + ca-certificates  2024.8.30  hbcca054_0    conda-forge     Cached
#   - libgomp             13.2.0  h77fa898_6    conda-forge      420kB
#   + libgomp             14.1.0  h77fa898_1    conda-forge     Cached
#   - libgcc-ng           13.2.0  h77fa898_6    conda-forge      778kB
#   + libgcc-ng           14.1.0  h69a702a_1    conda-forge     Cached
#   - openssl              3.3.1  h4ab18f5_0    conda-forge        3MB
#   + openssl              3.3.2  hb9d3cd8_0    conda-forge     Cached
#
#   Summary:
#
#   Install: 2 packages
#   Upgrade: 5 packages
#
#   Total download: 91kB
#
# ──────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B html5lib                   0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0shtml5lib                                            91.3kB @   1.1MB/s  0.1s
# [+] 0.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  91.3kB                            0.1s
# Extracting   (1) ━━━━━━━━━━━━━━━╸━━━━━━━       0 html5lib                   0.0s
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ERROR conda.core.link:_execute(949): An error occurred while uninstalling package 'conda-forge/noarch::certifi-2024.6.2-pyhd8ed1ab_0'.
# Rolling back transaction: done
# [Errno 13] Permission denied: '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER' -> '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER.c~'
# ()
#
#
# [Errno 13] Permission denied: '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER' -> '/opt/conda/lib/python3.11/site-packages/certifi-2024.6.2.dist-info/INSTALLER.c~'
# ()
#
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests==2.26.0)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests==2.26.0) (2024.6.2)
# Collecting charset-normalizer~=2.0.0 (from requests==2.26.0)
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests==2.26.0) (3.7)
# Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 10.0 MB/s eta 0:00:00
# Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 20.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, charset-normalizer, requests
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 24.4.0 requires requests<3,>=2.28.0, but you have requests 2.26.0 which is incompatible.
# yfinance 0.2.43 requires requests>=2.31, but you have requests 2.26.0 which is incompatible.
# jupyterlab-server 2.27.1 requires requests>=2.31, but you have requests 2.26.0 which is incompatible.
# Successfully installed charset-normalizer-2.0.12 requests-2.26.0 urllib3-1.26.20

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Set the url

# %%
import yfinance as yf

# Get Tesla data
tesla = yf.Ticker('TSLA')

# Get revenue data (financials)
tesla_revenue = tesla.financials.T
tesla_revenue.tail()
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2023-12-31                         0.0               0.21     14796000000.0
# 2022-12-31                 -14080000.0               0.08     17833000000.0
# 2021-12-31                   2970000.0               0.11      9598000000.0
# 2020-12-31                         0.0               0.25      4224000000.0
# 2019-12-31                         NaN                NaN               NaN
#
#            Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 2023-12-31                 0.0                                    0.0
# 2022-12-31        -176000000.0                           -176000000.0
# 2021-12-31          27000000.0                             27000000.0
# 2020-12-31                 0.0                                    0.0
# 2019-12-31                 NaN                                    NaN
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2023-12-31                                      14999000000.0
# 2022-12-31                                      12583000000.0
# 2021-12-31                                       5524000000.0
# 2020-12-31                                        721000000.0
# 2019-12-31                                                NaN
#
#            Reconciled Depreciation Reconciled Cost Of Revenue         EBITDA  \
# 2023-12-31            4667000000.0              79113000000.0  14796000000.0
# 2022-12-31            3747000000.0              60609000000.0  17657000000.0
# 2021-12-31            2911000000.0              40217000000.0   9625000000.0
# 2020-12-31            2322000000.0              24906000000.0   4224000000.0
# 2019-12-31                     NaN                        NaN            NaN
#
#                      EBIT  ... Interest Expense Non Operating  \
# 2023-12-31  10129000000.0  ...                    156000000.0
# 2022-12-31  13910000000.0  ...                    191000000.0
# 2021-12-31   6714000000.0  ...                    371000000.0
# 2020-12-31   1902000000.0  ...                    748000000.0
# 2019-12-31            NaN  ...                            NaN
#
#            Interest Income Non Operating Operating Income Operating Expense  \
# 2023-12-31                  1066000000.0     8891000000.0      8769000000.0
# 2022-12-31                   297000000.0    13832000000.0      7021000000.0
# 2021-12-31                    56000000.0     6496000000.0      7110000000.0
# 2020-12-31                    30000000.0     1994000000.0      4636000000.0
# 2019-12-31                           NaN              NaN               NaN
#
#            Research And Development Selling General And Administration  \
# 2023-12-31             3969000000.0                       4800000000.0
# 2022-12-31             3075000000.0                       3946000000.0
# 2021-12-31             2593000000.0                       4517000000.0
# 2020-12-31             1491000000.0                       3145000000.0
# 2019-12-31                      NaN                                NaN
#
#              Gross Profit Cost Of Revenue  Total Revenue Operating Revenue
# 2023-12-31  17660000000.0   79113000000.0  96773000000.0     96773000000.0
# 2022-12-31  20853000000.0   60609000000.0  81462000000.0     81462000000.0
# 2021-12-31  13606000000.0   40217000000.0  53823000000.0     53823000000.0
# 2020-12-31   6630000000.0   24906000000.0  31536000000.0     31536000000.0
# 2019-12-31            NaN             NaN            NaN               NaN
#
# [5 rows x 47 columns]
